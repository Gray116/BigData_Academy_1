# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.Container {width:85% !important;}
div.CodeMirror {font-family:나눔고딕; font-size:13pt; line-height : 150%;}
div.output_area pre {font-family:나눔고딕; font-size:13pt; line-height : 150%;}
div.output_wrapper pre {font-family:나눔고딕; font-size:13pt; line-height : 150%;}
div.input {font-family:나눔고딕; font-size:13pt; line-height : 150%;}
</style>
"""))
# Out:
# <style>
# div.Container {width:85% !important;}
# div.CodeMirror {font-family:나눔고딕; font-size:13pt; line-height : 150%;}
# div.output_area pre {font-family:나눔고딕; font-size:13pt; line-height : 150%;}
# div.output_wrapper pre {font-family:나눔고딕; font-size:13pt; line-height : 150%;}
# div.input {font-family:나눔고딕; font-size:13pt; line-height : 150%;}
# </style>

# %%
import pandas as pd # 데이터 프레임화 해야하기 때문
import numpy as np

# %%
# ▶ 1. 데이터 셋 불러오기
df1 = pd.read_csv('D:/Gray_Bigdata/src/00_Projects/data/18_19_players/eng_1819_defensive_stats.csv',
                  encoding = "UTF8")
df2 = pd.read_csv('D:/Gray_Bigdata/src/00_Projects/data/18_19_players/eng_1819_offensive_stats.csv',
                  encoding = "UTF8")
df3 = pd.read_csv('D:/Gray_Bigdata/src/00_Projects/data/18_19_players/eng_1819_passing_stats.csv', 
                  encoding = "UTF8")

# %%
# ▶ 2. 결측치 변경 및 필요없는 열 제거
df1 = df1.replace(np.nan, "0.0")
df2 = df2.replace(np.nan, "0.0")
df3 = df3.replace(np.nan, "0.0")

df1.head()
# Out:
#    Unnamed: 0           Player Tackles Inter Fouls Offsides Clear  Drb Blocks  \
# 0           0      Eden Hazard     0.4   0.4   0.3      0.0   0.1  0.3    0.0
# 1           1  Raheem Sterling     0.9   0.5   1.2      0.0   0.1  0.5    0.1
# 2           2    Mohamed Salah     0.6   0.1   0.7      0.0   0.1  0.3    0.0
# 3           3    Sergio Agüero     0.5   0.3   0.6      0.0   0.1  0.1    0.0
# 4           4  Virgil van Dijk     1.0   1.1   0.3      1.1   5.2  0.0    0.5
#
#   OwnG  Rating
# 0  0.0    7.81
# 1  0.0    7.61
# 2  0.0    7.57
# 3  0.0    7.53
# 4  0.0    7.44

# %%
df1.drop(['Unnamed: 0'], axis = 1, inplace = True)
df1.drop(['Unnamed: 0'], axis = 1, inplace = True)
df1.drop(['Unnamed: 0'], axis = 1, inplace = True)

df1.head()
# Out:
#             Player Tackles Inter Fouls Offsides Clear  Drb Blocks OwnG  Rating
# 0      Eden Hazard     0.4   0.4   0.3      0.0   0.1  0.3    0.0  0.0    7.81
# 1  Raheem Sterling     0.9   0.5   1.2      0.0   0.1  0.5    0.1  0.0    7.61
# 2    Mohamed Salah     0.6   0.1   0.7      0.0   0.1  0.3    0.0  0.0    7.57
# 3    Sergio Agüero     0.5   0.3   0.6      0.0   0.1  0.1    0.0  0.0    7.53
# 4  Virgil van Dijk     1.0   1.1   0.3      1.1   5.2  0.0    0.5  0.0    7.44
