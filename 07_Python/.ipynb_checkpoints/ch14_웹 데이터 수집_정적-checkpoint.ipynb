# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.CodeMirror {font-family:Consolas; font-size:13pt;}
div.output {font-size:13pt; font-weight : bold;}
div.input {font-family:Consolas; font-size:13pt;}
</style>
"""))
# Out:
# <style>
# div.CodeMirror {font-family:Consolas; font-size:13pt;}
# div.output {font-size:13pt; font-weight : bold;}
# div.input {font-family:Consolas; font-size:13pt;}
# </style>

# %% [markdown]
# <b><font color = "red" size = "6">ch14. 웹 데이터 수집</font></b>

# %% [markdown]
# # 1절. BeautifulSoup와 parser
# `pip install bs4` 아나콘다를 설치하면 자동설치 된다.<br>
# `pip install requests_file`
#
# [공식 사이트](https://www.crummy.com/software/BeautifulSoup)<br>
# [Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc)

# %%
import requests
from requests_file import FileAdapter

# %%
s = requests.Session()

s.mount('file://', FileAdapter())
response = s.get('file:///D:/Gray_Bigdata/src/07_Python/ch14_sample.html')

response
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
    print('성공')

if response.status_code == 404:
    print('Not Found')
# Out:
# 성공

# %%
response.content
# Out:
# b'\n<!-- saved from url=(0055)file:///D:/Gray_Bigdata/Note/07_Python/ch14_sample.html -->\n<html><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n        <title>HTML sample</title>\n        <style>\n            span {color:red;}\n        </style>\n    </head>\n    <body>\n        <h1 class="greeting css">Hello CSS</h1>\n        <h1 class="css">Hi CSS</h1>\n        <div id="subject">\xec\x84\xa0\xed\x83\x9d\xec\x9e\x90</div>\n        <p>CSS \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\x8a\x94 \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xea\xb3\xb3\xec\x97\x90 \xed\x99\x9c\xec\x9a\xa9\xeb\x90\xa9\xeb\x8b\x88\xeb\x8b\xa4</p>\n        <div class="contents">\xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\xa5\xbc \xec\x96\xb4\xeb\x96\xbb\xea\xb2\x8c \xec\x9e\x91\xec\x84\xb1\xed\x95\x98\xeb\x8a\x90\xeb\x83\x90\xec\x97\x90 \xeb\x94\xb0\xeb\x9d\xbc \n\t<span>\xeb\x8b\xa4\xeb\xa5\xb8 <b>\xec\x9a\x94\xec\x86\x8c\xea\xb0\x80 \xeb\xb0\x98\xed\x99\x98</b></span>\xeb\x90\xa9\xeb\x8b\x88\xeb\x8b\xa4.\n        </div>\n        <div>CSS\xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\x8a\x94 \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xea\xb3\xb3\xec\x97\x90 <b>\xed\x99\x9c\xec\x9a\xa9</b>\xeb\x90\xa9\xeb\x8b\x88\xeb\x8b\xa4</div>\n        <input type="text" name="passwd" id="passwd">\n    \n\n\n\n\n</body></html>'

# %%
response.content.decode('UTF8')
# Out:
# '\n<!-- saved from url=(0055)file:///D:/Gray_Bigdata/Note/07_Python/ch14_sample.html -->\n<html><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n        <title>HTML sample</title>\n        <style>\n            span {color:red;}\n        </style>\n    </head>\n    <body>\n        <h1 class="greeting css">Hello CSS</h1>\n        <h1 class="css">Hi CSS</h1>\n        <div id="subject">선택자</div>\n        <p>CSS 선택자는 다양한 곳에 활용됩니다</p>\n        <div class="contents">선택자를 어떻게 작성하느냐에 따라 \n\t<span>다른 <b>요소가 반환</b></span>됩니다.\n        </div>\n        <div>CSS선택자는 다양한 곳에 <b>활용</b>됩니다</div>\n        <input type="text" name="passwd" id="passwd">\n    \n\n\n\n\n</body></html>'

# %%
# html parsing
from bs4 import BeautifulSoup as bs
soup = bs(response.content, "html.parser")

soup
# Out:
# <!-- saved from url=(0055)file:///D:/Gray_Bigdata/Note/07_Python/ch14_sample.html -->
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>HTML sample</title>
# <style>
#             span {color:red;}
#         </style>
# </head>
# <body>
# <h1 class="greeting css">Hello CSS</h1>
# <h1 class="css">Hi CSS</h1>
# <div id="subject">선택자</div>
# <p>CSS 선택자는 다양한 곳에 활용됩니다</p>
# <div class="contents">선택자를 어떻게 작성하느냐에 따라
# 	<span>다른 <b>요소가 반환</b></span>됩니다.
#         </div>
# <div>CSS선택자는 다양한 곳에 <b>활용</b>됩니다</div>
# <input id="passwd" name="passwd" type="text"/>
# </body></html>

# %%
# 선택자
# 처음 나오는 h1태그
el = soup.select_one('h1')

print('el ->', el)
print('el.text :', el.text)
print('el.string :', el.string)
print('el의 속성들 :', el.attrsrs)
print('el의 class속성 :', el.attrs['class'])
print('el의 name :', el.name)
# Out:
# el -> <h1 class="greeting css">Hello CSS</h1>
# el.text : Hello CSS
# el.string : Hello CSS
# el의 속성들 : None
# el의 class속성 : ['greeting', 'css']
# el의 name : h1

# %%
# h1태그들 전부 선택, 없는 태그는 빈 스트링. 한 엘리먼트만 있어도 리스트로 반환
el = soup.select('h1')

print('el :', el)
print('el의 text들 :', [e.text for e in el])
print('el의 string들 :', [e.string for e in el])
print('el의 속성들 :', [e.attrs for e in el])
print('el의 class속성들 :', [e.attrs['class'] for e in el])
# Out:
# el : [<h1 class="greeting css">Hello CSS</h1>, <h1 class="css">Hi CSS</h1>]
# el의 text들 : ['Hello CSS', 'Hi CSS']
# el의 string들 : ['Hello CSS', 'Hi CSS']
# el의 속성들 : [{'class': ['greeting', 'css']}, {'class': ['css']}]
# el의 class속성들 : [['greeting', 'css'], ['css']]

# %%
# select(선택자, 선택자), find_all(선택자하나) 유사하다.
soup.find_all('h1')
soup.select('h1, p')
# Out:
# [<h1 class="greeting css">Hello CSS</h1>,
#  <h1 class="css">Hi CSS</h1>,
#  <p>CSS 선택자는 다양한 곳에 활용됩니다</p>]

# %%
# select_one(선택자), find(태그) 유사하다.
soup.select_one('h1.greeting.css')
# Out:
# <h1 class="greeting css">Hello CSS</h1>

# %%
soup.select('h1.greeting.css')[0]
# Out:
# <h1 class="greeting css">Hello CSS</h1>

# %% [markdown]
# # 2절. 정적 웹 크롤링

# %% [markdown]
# ## 2.1 requests 모듈(GET 요청)

# %%
import requests
response = requests.get('http://api.github.com')

response
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
    print('Success')
elif response.status_code == 404:
    print('Not found')
elif response.status_code == 406:
    print('웹 크롤링 허용불가')
# Out:
# Success

# %%
response.content
# Out:
# b'{\n  "current_user_url": "https://api.github.com/user",\n  "current_user_authorizations_html_url": "https://github.com/settings/connections/applications{/client_id}",\n  "authorizations_url": "https://api.github.com/authorizations",\n  "code_search_url": "https://api.github.com/search/code?q={query}{&page,per_page,sort,order}",\n  "commit_search_url": "https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}",\n  "emails_url": "https://api.github.com/user/emails",\n  "emojis_url": "https://api.github.com/emojis",\n  "events_url": "https://api.github.com/events",\n  "feeds_url": "https://api.github.com/feeds",\n  "followers_url": "https://api.github.com/user/followers",\n  "following_url": "https://api.github.com/user/following{/target}",\n  "gists_url": "https://api.github.com/gists{/gist_id}",\n  "hub_url": "https://api.github.com/hub",\n  "issue_search_url": "https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}",\n  "issues_url": "https://api.github.com/issues",\n  "keys_url": "https://api.github.com/user/keys",\n  "label_search_url": "https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}",\n  "notifications_url": "https://api.github.com/notifications",\n  "organization_url": "https://api.github.com/orgs/{org}",\n  "organization_repositories_url": "https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}",\n  "organization_teams_url": "https://api.github.com/orgs/{org}/teams",\n  "public_gists_url": "https://api.github.com/gists/public",\n  "rate_limit_url": "https://api.github.com/rate_limit",\n  "repository_url": "https://api.github.com/repos/{owner}/{repo}",\n  "repository_search_url": "https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}",\n  "current_user_repositories_url": "https://api.github.com/user/repos{?type,page,per_page,sort}",\n  "starred_url": "https://api.github.com/user/starred{/owner}{/repo}",\n  "starred_gists_url": "https://api.github.com/gists/starred",\n  "user_url": "https://api.github.com/users/{user}",\n  "user_organizations_url": "https://api.github.com/user/orgs",\n  "user_repositories_url": "https://api.github.com/users/{user}/repos{?type,page,per_page,sort}",\n  "user_search_url": "https://api.github.com/search/users?q={query}{&page,per_page,sort,order}"\n}\n'

# %%
response.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %% [markdown]
# ## 2.2 BeautifulSoup 모듈을 사용한 웹 데이터 수집
# - HTML, XML 등 Markup 언어를 crawling 하기 위한 대표적인 모듈
# - http://www.crummy.com/software/BeautifulSoup

# %% [markdown]
# ### 2.2.1 연습1) 환율정보 가져오기 (네이버 금융 -> 시장지표)
# - [네이버 금융 시장지표](https://finance.naver.com/marketindex/)

# %%
import requests
from bs4 import BeautifulSoup as bs
from numpy import round
url = 'https://finance.naver.com/marketindex'
market_idx = requests.get(url)
soup = bs(market_idx.content, "html.parser")
price = soup.select('div.head_info > span.value')

[ round(float(p.text.replace(',', '')), 2) for p in price ]
# Out:
# [1149.6,
#  1041.4,
#  1349.23,
#  177.37,
#  110.27,
#  1.17,
#  1.38,
#  92.93,
#  66.48,
#  1647.36,
#  1723.4,
#  64075.42]

# %%
[ round(float(''.join(p.text.split(','))), 1) for p in price ]
# Out:
# [1149.6,
#  1041.4,
#  1349.2,
#  177.4,
#  110.3,
#  1.2,
#  1.4,
#  92.9,
#  66.5,
#  1647.4,
#  1723.4,
#  64075.4]

# %%
for idx in range(len(price)):
    print(price[idx].text, end='\t')
# Out:
# 1,149.60	1,041.40	1,349.23	177.37	110.2700	1.1744	1.3846	92.9300	66.48	1647.36	1723.4	64075.42

# %%
title = soup.select('h3.h_lst > span.blind')

for idx in range(len(title)):
    print(title[idx].text, end='\t')
# Out:
# 미국 USD	일본 JPY(100엔)	유럽연합 EUR	중국 CNY	달러/일본 엔	유로/달러	영국 파운드/달러	달러인덱스	WTI	휘발유	국제 금	국내 금

# %%
unit = soup.select('div.head_info > span > span.blind')
unit = [u.text for u in unit]
unit.insert(7,'')
unit
# Out:
# ['원', '원', '원', '원', '엔', '달러', '달러', '', '달러', '원', '달러', '원']

# %%
status = soup.select('div.head_info > span.blind')

for idx in range(len(status)):
    print(status[idx].text, end=', ')
# Out:
# 상승, 상승, 상승, 상승, 상승, 하락, 하락, 상승, 하락, 상승, 하락, 하락,

# %%
for idx in range(len(title)):
    print("{} : {}{} - {}".format(title[idx].text, price[idx].text, 
                                  unit[idx], status[idx].text))
# Out:
# 미국 USD : 1,149.60원 - 상승
# 일본 JPY(100엔) : 1,041.40원 - 상승
# 유럽연합 EUR : 1,349.23원 - 상승
# 중국 CNY : 177.37원 - 상승
# 달러/일본 엔 : 110.2700엔 - 상승
# 유로/달러 : 1.1744달러 - 하락
# 영국 파운드/달러 : 1.3846달러 - 하락
# 달러인덱스 : 92.9300 - 상승
# WTI : 66.48달러 - 하락
# 휘발유 : 1647.36원 - 상승
# 국제 금 : 1723.4달러 - 하락
# 국내 금 : 64075.42원 - 하락

# %% [markdown]
# ### 2.2.2 연습2) 네이버 영화 랭킹 가져오기
# ```
# 9위 영화제목 - 영화소개 url
# 감독 및 배우
# xxx : 감독 / xxx : 주연 / xxx : 주연
# ```

# %%
# ▶ 영화순위, 영화제목, 소개url, 조연
# import requests
# from bs4 import BeautifulSoup as bs
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'

movie_ranking = requests.get(url)
soup = bs(movie_ranking.content, 'html.parser')
title_list = soup.select('td.title > div.tit3 > a') # 영화제목

for idx in range(len(title_list)): # 영화순위 + 영화제목 출력하기
    link = url + title_list[idx].attrs['href']
    print("{:2d}위 영화 : {} - {}".format(idx+1, title_list[idx].text, link))
    
    page = requests.get(link) # link에서 주소를 얻어 page에 저장
    s = bs(page.content, "html.parser")
    
    people = s.select('li a.tx_people') # 사람이름
    staffs = s.select('dl.staff > dt') # 역할
    
    print('감독 및 배우')
    for idx in range(len(people)):
        print('{} : {}'.format(people[idx].text, staffs[idx].text), end = ' / ')
    print() # 자동 개행
# Out:
#  1위 영화 : 모가디슈 - https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=192150
# 감독 및 배우
# 류승완 : 감독 / 김윤석 : 주연 / 조인성 : 주연 / 허준호 : 주연 / 구교환 : 주연 / 김소진 : 주연 /
#  2위 영화 : 더 수어사이드 스쿼드 - https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=167569
# 감독 및 배우
# 제임스 건 : 감독 / 마고 로비 : 주연 / 이드리스 엘바 : 주연 / 존 시나 : 주연 / 조엘 킨나만 : 주연 / 실베스터 스탤론 : 주연 /
#  3위 영화 : 방법: 재차의 - https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=200785
# 감독 및 배우
# 김용완 : 감독 / 엄지원 : 주연 / 정지소 : 주연 / 정문성 : 조연 / 김인권 : 조연 / 고규필 : 조연 /
#  4위 영화 : 정글 크루즈 - https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=179406
# 감독 및 배우
# 자움 콜렛 세라 : 감독 / 드웨인 존슨 : 주연 / 에밀리 블런트 : 주연 / 에드가 라미레즈 : 조연 / 제시 플레먼스 : 조연 / 폴 지아마티 : 조연 /
#  5위 영화 : 블랙 위도우 - https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code
- https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=194097
# 감독 및 배우
# 김미조 : 감독 / 정애화 : 주연 / 장유 : 조연 / 고서희 : 조연 / 김가빈 : 조연 / 김병춘 : 조연 /
# 48위 영화 : 오필리아 - https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=168074
# 감독 및 배우
# 클레어 맥카시 : 감독 / 데이지 리들리 : 주연 / 조지 맥케이 : 주연 / 나오미 왓츠 : 주연 / 클라이브 오웬 : 주연 / 톰 펠튼 : 조연 /
# 49위 영화 : 졸트 - https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=205981
# 감독 및 배우
# 타니아 웩슬러 : 감독 / 케이트 베킨세일 : 주연 / 제이 코트니 : 주연 / 스탠리 투치 : 주연 / 바비 카나베일 : 주연 /
# 50위 영화 : 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들 - https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=205968
# 감독 및 배우
# 쿄고쿠 타카히코 : 감독 / 박영남 : 주연 / 김환진 : 주연 / 강희선 : 주연 / 여민정 : 주연 / 정유미 : 주연 /

# %%
# import requests
# from bs4 import BeautifulSoup as bs
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'

movie_ranking = requests.get(url)
soup = bs(movie_ranking.content, 'html.parser')
title_list = soup.select('td.title > div.tit3 > a') # 영화제목

dict_list = []
for idx in range(len(title_list)): # 영화순위 + 영화제목 출력하기
    dic = {} # 빈 딕셔너리
    dic['rank'] = idx+1
    dic['title'] = title_list[idx].text
    dic['link'] = url + title_list[idx].attrs['href']
    
    page = requests.get(dic['link']) # link에서 주소를 얻어 page에 저장
    s = bs(page.content, "html.parser")
    people = s.select('li a.tx_people') # 사람이름
    staffs = s.select('dl.staff > dt') # 역할
    
    dic['staff'] = ''
    for idx in range(len(people)):
        dic['staff'] += "{} : {} / ".format(people[idx].text, staffs[idx].text)        
    dict_list.append(dic) # 자동 개행

dict_list
# Out:
# [{'rank': 1,
#   'title': '모가디슈',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=192150',
#   'staff': '류승완 : 감독 / 김윤석 : 주연 / 조인성 : 주연 / 허준호 : 주연 / 구교환 : 주연 / 김소진 : 주연 / '},
#  {'rank': 2,
#   'title': '더 수어사이드 스쿼드',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=167569',
#   'staff': '제임스 건 : 감독 / 마고 로비 : 주연 / 이드리스 엘바 : 주연 / 존 시나 : 주연 / 조엘 킨나만 : 주연 / 실베스터 스탤론 : 주연 / '},
#  {'rank': 3,
#   'title': '방법: 재차의',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=200785',
#   'staff': '김용완 : 감독 / 엄지원 : 주연 / 정지소 : 주연 / 정문성 : 조연 / 김인권 : 조연 / 고규필 : 조연 / '},
#  {'rank': 4,
#   'title': '정글 크루즈',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=179406',
#   'staff': '자움 콜렛 세라 : 감독 / 드웨인 존슨 : 주연 / 에밀리 블런트 : 주연 / 에드가 라미레즈 : 조연 / 제시 플레먼스 : 조연 / 폴 지아마티 : 조연 / '},
#  {'rank': 5,
#   'title': '블랙 위도우',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=184318',
#   'staff': '케이트 쇼트랜드 : 감독 / 스칼릿 조핸슨 : 주연 / 플로렌스 퓨 : 주연 / 레이첼 와이즈 : 주연 / 데이빗 하버 : 주연 / 레이 윈스턴 : 조연 / '},
#  {'rank': 6,
#   'title': '그린 나이트',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=204768',
#   'staff': '데이빗 로워리 : 감독 / 데브 파텔 : 주연 / 알리시아 비칸데르 : 주연 / 조엘 에저튼 : 주연 / 사리타 초우드리 : 주연 / 랄프 이네슨 : 주연 / '},
#  {'rank': 7,
#   'title': '싱크홀',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code

#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=129687',
#   'staff': '크리스티안 펫졸드 : 감독 / 니나 호스 : 주연 / 로날드 제르필드 : 주연 / 니나 쿤젠도르프 : 주연 / 트리스탄 퓨터 : 조연 / 발레리 코흐 : 조연 / '},
#  {'rank': 21,
#   'title': '귀문',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=206168',
#   'staff': '심덕근 : 감독 / 김강우 : 주연 / 김소혜 : 주연 / 이정형 : 주연 / 홍진기 : 주연 / '},
#  {'rank': 22,
#   'title': '암살자들',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=191929',
#   'staff': '라이언 화이트 : 감독 / '},
#  {'rank': 23,
#   'title': '킬러의 보디가드 2: 킬러의 와이프',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=204624',
#   'staff': '패트릭 휴즈 : 감독 / 라이언 레이놀즈 : 주연 / 사무엘 L. 잭슨 : 주연 / 셀마 헤이엑 : 주연 / 모건 프리먼 : 조연 / 안토니오 반데라스 : 조연 / '},
#  {'rank': 24,
#   'title': '크루엘라',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=187322',
#   'staff': '크레이그 질레스피 : 감독 / 엠마 스톤 : 주연 / 엠마 톰슨 : 조연 / 마크 스트롱 : 조연 / 폴 월터 하우저 : 조연 / 에밀리 비샴 : 조연 / '},
#  {'rank': 25,
#   'title': '발신제한',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=194205',
#   'staff': '김창주 : 감독 / 조우진 : 주연 / 이재인 : 주연 / 진경 : 주연 / 김지호 : 조연 / '},
#  {'rank': 26,
#   'title': '화양연화',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=28876',
#   'staff': '왕가위 : 감독 / 장만옥 : 주연 / 양조위 : 주연 / 뇌진 : 조연 / 반적화 : 조연 / 손가군 : 조연 / '},
#  {'rank': 27,
#   'title': '수어사이드 스쿼드',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=126032',
#   'staff': '데이비드 에이어 : 감독 / 윌 스미스 : 주연 / 자레드 레토 : 주연 / 마고 로비 : 주연 / 카라 델레바인 : 주연 / 제이 코트니 : 주연 / '},
#  {'rank': 28,
#   'title': '나만 보이니',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=205614',
#   'staff': '임용재 : 감독 / 정진운 : 주연 / 솔빈 : 주연 / 곽희성 : 조연 / 훈 : 조연 / 이순원 : 조연 / '},
#  {'rank': 29,
#   'title': '우리, 둘',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=188466',
#   'staff': '필리포 메네게티 : 감독 / 바바라 수코바 : 주연 / 마틴 슈발리에 : 주연 / 레아 드루케 : 조연 / 제롬 바랑프랭 : 조연 / 허브 소근 : 조연 / '},
#  {'rank': 30,
#   'title': '블랙핑크 더 무비',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=206577',
#   'staff': '오윤동 : 감독 / 블랙핑크 : 주연 / '},
#  {'rank': 31,
#   'title': '베놈 2: 렛 데어 비 카니지',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=187323',
#   'staff': '앤디 서키스 : 감독 / 톰 하디 : 주연 / 미셸 윌리엄스 : 주연 / 나오미 해리스 : 조연 / 레이드 스콧 : 조연 / 스티븐 그레이엄 : 조연 / '},
#  {'rank': 32,
#   'title': '신 강시선생',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=206030',
#   'staff': '유관위 : 감독 / 전소호 : 주연 / 서소강 : 주연 / '},
#  {'rank': 33,
#   'title': '루카',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=202903',
#   'staff': '엔리코 카사로사 : 감독 / 제이콥 트렘블레이 : 주연 / 잭 딜런 그레이저 : 주연 / 엠마 버만 : 주연 / 사베리오 라이몬도 : 조연 / 마야 루돌프 : 조연 / '},
#  {'rank': 34,
#   'title': '귀신',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=194887',
#   'staff': '정하용 : 감독 / 정이랑 : 주연 / 함건수 : 주연 / 최이태 : 주연 / '},
#  {'rank': 35,
#   'title': '콰이어트 플레이스 2',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=189368',
#   'staff': '존 크래신스키 : 감독 / 에밀리 블런트 : 주연 / 킬리언 머피 : 주연 / 밀리센트 시몬스 : 주연 / 노아 주프 : 주연 / 디몬 하운수 : 조연 / '},
#  {'rank': 36,
#   'title': '그린 북',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=171539',
#   'staff': '피터 패럴리 : 감독 / 비고 모텐슨 : 주연 / 마허샬라 알리 : 주연 / 린다 카델리니 : 조연 / 세바스찬 매니스캘코 : 조연 / 디미터 D. 마리노프 : 조연 / '},
#  {'rank': 37,
#   'title': '이도공간',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=35360',
#   'staff': '나지량 : 감독 / 장국영 : 주연 / 임가흔 : 주연 / 이자웅 : 조연 / 주가령 : 조연 / 서소강 : 조연 / '},
#  {'rank': 38,
#   'title': '베스트 오퍼',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=101248',
#   'staff': '쥬세페 토르나토레 : 감독 / 제프리 러쉬 : 주연 / 짐 스터게스 : 주연 / 실비아 획스 : 주연 / 도날드 서덜랜드 : 주연 / 필립 잭슨 : 조연 / '},
#  {'rank': 39,
#   'title': '더 스웜',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=197750',
#   'staff': '저스트 필리포트 : 감독 / 설리안 브라힘 : 주연 / 소피앙 캄 : 주연 / '},
#  {'rank': 40,
#   'title': '먼 훗날 우리',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=175092',
#   'staff': '유약영 : 감독 / 정백연 : 주연 / 주동우 : 주연 / 톈좡좡 : 주연 / 쑤샤오밍 : 조연 / 시여비 : 조연 / '},
#  {'rank': 41,
#   'title': '내겐 너무 소중한 너',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=201898',
#   'staff': '이창원 : 감독 / 진구 : 주연 / 정서연 : 주연 / 강신일 : 조연 / 장혜진 : 조연 / 박예니 : 조연 / '},
#  {'rank': 42,
#   'title': '가버나움',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=174830',
#   'staff': '나딘 라바키 : 감독 / 자인 알 라피아 : 주연 / 요르다노스 시프로우 : 주연 / 보루와티프 트레저 반콜 : 조연 / 나딘 라바키 : 조연 / 하이타 아이잠 : 조연 / '},
#  {'rank': 43,
#   'title': '생각의 여름',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=194082',
#   'staff': '김종재 : 감독 / 김예은 : 주연 / 곽민규 : 주연 / 오규철 : 주연 / 한해인 : 주연 / 신기환 : 주연 / '},
#  {'rank': 44,
#   'title': '극장판 귀멸의 칼날: 무한열차편',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=196051',
#   'staff': '소토자키 하루오 : 감독 / 하나에 나츠키 : 주연 / 키토 아카리 : 주연 / 시모노 히로 : 조연 / 마츠오카 요시츠구 : 조연 / 히노 사토시 : 조연 / '},
#  {'rank': 45,
#   'title': '우리는 매일매일',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=188195',
#   'staff': '강유가람 : 감독 / 허은주 : 주연 / 김이승현 : 주연 / 유여원 : 주연 / 김혜정 : 주연 / 강정임 : 주연 / '},
#  {'rank': 46,
#   'title': '꽃다발 같은 사랑을 했다',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=200896',
#   'staff': '도이 노부히로 : 감독 / 아리무라 카스미 : 주연 / 스다 마사키 : 주연 / 키요하라 카야 : 주연 / 호소다 카나타 : 주연 / 칸 하나에 : 조연 / '},
#  {'rank': 47,
#   'title': '갈매기',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code=194097',
#   'staff': '김미조 : 감독 / 정애화 : 주연 / 장유 : 조연 / 고서희 : 조연 / 김가빈 : 조연 / 김병춘 : 조연 / '},
#  {'rank': 48,
#   'title': '오필리아',
#   'link': 'https://movie.naver.com/movie/sdb/rank/rmovie.naver/movie/bi/mi/basic.naver?code
# 47    48  ...  클레어 맥카시 : 감독 / 데이지 리들리 : 주연 / 조지 맥케이 : 주연 / 나오...
# 48    49  ...  타니아 웩슬러 : 감독 / 케이트 베킨세일 : 주연 / 제이 코트니 : 주연 / 스...
# 49    50  ...  쿄고쿠 타카히코 : 감독 / 박영남 : 주연 / 김환진 : 주연 / 강희선 : 주연...
#
# [50 rows x 4 columns]

# %% [markdown]
# ### 2.2.3 연습3) 이번주 로또 번호 출력
# ```
# 975회(2021년 08월 07일 추첨)
# 당첨번호 [7, 8, 9, 17, 22, 24]
# 보너스번호 : 5
# ```

# %%
# 네트워크가 방화벽 or 사이트에서 크롤링을 막아놓으면 실행 안된다.
# from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'

lottery = urlopen(url)
# lottery = requests.get(url)

soup = bs(lottery.content, 'html.parser')

soup
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# ~\anaconda3\lib\http\client.py in connect(self)
#    1416
# -> 1417             super().connect()
#    1418
#
# ~\anaconda3\lib\http\client.py in connect(self)
#     920         """Connect to the host and port specified in __init__."""
# --> 921         self.sock = self._create_connection(
#     922             (self.host,self.port), self.timeout, self.source_address)
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-84-41b0881deef1> in <module>
#       3 url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'
#       4
# ----> 5 lottery = urlopen(url)
#       6 # lottery = requests.get(url)
#       7 soup = bs(lottery.content, 'html.parser')
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1395
#    1396         def https_open(self, req):
# -> 1397             return self.do_open(http.client.HTTPSConnection, req,
#    1398                 context=self._context, check_hostname=self._check_hostname)
#    1399
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#    1356             except OSError as err: # timeout error
# -> 1357                 raise URLError(err)
#    1358             r = h.getresponse()
#    1359         except:
#
# URLError: <urlopen error [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다>

# %% [markdown]
# ### 2.2.4 연습4) 크롤링을 막아놓은 사이트 크롤링하기

# %%
# from bs4 import BeautifulSoup as bs
# import requests
url = 'https://www.melon.com/chart/'

melon_page = requests.get(url)
melon_page
# Out:
# <Response [406]>

# %%
# 크롤링을 막아놓은 경우 크롤링 방법
headers = {'User-agent':'Mozilla/5.0'} # 모질라 브라우저에서 가져온 것처럼 트릭
melon_page = requests.get(url, headers = headers)

soup = bs(melon_page.content, "html.parser")

title = soup.select('div.wrap_song_info > div.ellipsis.rank01 > span > a')
singer = soup.select('div.ellipsis.rank02 > span.checkEllipsis')

for idx in range(len(title)):
    print("{:3d}위 | {} | {}".format(idx+1, title[idx].text, singer[idx].text))
# Out:
#   1위 | 신호등 | 이무진
#   2위 | 바라만 본다 | MSG워너비(M.O.M)
#   3위 | 낙하 (with 아이유) | AKMU (악뮤)
#   4위 | Next Level | aespa
#   5위 | Permission to Dance | 방탄소년단
#   6위 | Butter | 방탄소년단
#   7위 | Weekend | 태연 (TAEYEON)
#   8위 | 헤픈 우연 | 헤이즈 (Heize)
#   9위 | Peaches (Feat. Daniel Caesar & Giveon) | Justin Bieber
#  10위 | 좋아좋아 | 조정석
#  11위 | Dynamite | 방탄소년단
#  12위 | Dun Dun Dance | 오마이걸 (OH MY GIRL)
#  13위 | OHAYO MY NIGHT | 디핵 (D-Hack), PATEKO (파테코)
#  14위 | 롤린 (Rollin') | 브레이브걸스
#  15위 | 치맛바람 (Chi Mat Ba Ram) | 브레이브걸스
#  16위 | Alcohol-Free | TWICE (트와이스)
#  17위 | 비와 당신 | 이무진
#  18위 | 라일락 | 아이유
#  19위 | ASAP | STAYC(스테이씨)
#  20위 | 나를 아는 사람 | MSG워너비(정상동기)
#  21위 | Celebrity | 아이유
#  22위 | 안녕 (Hello) | 조이 (JOY)
#  23위 | 하루만 더 | 빅마마
#  24위 | 이제 나만 믿어요 | 임영웅
#  25위 | 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco) | 호미들
#  26위 | 운전만해 (We Ride) | 브레이브걸스
#  27위 | 고백 | 10CM
#  28위 | Savage Love (Laxed - Siren Beat) (BTS Remix) | Jawsh 685, Jason Derulo, 방탄소년단
#  29위 | 비가 오는 날엔 (2021) | 헤이즈 (Heize)
#  30위 | DUMB DUMB | 전소미
#  31위 | 상상더하기 | 라붐 (LABOUM)
#  32위 | 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) | 방탄소년단
#  33위 | Bad Habits | Ed Sheeran
#  34위 | Timeless | SG 워너비
#  35위 | 멜로디 | ASH ISLAND
#  36위 | 내 손을 잡아 | 아이유
#  37위 | STAY | The Kid LAROI, Justin Bieber
#  38위 | 상상더하기 | MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인)
#  39위 | 밝게 빛나는 별이 되어 비춰줄게 | 송이한
#  40위 | 다정히 내 이름을 부르면 | 경서예지, 전건호
#  41위 | 봄날 | 방탄소년단
#  42위 | Life Goes On | 방탄소년단
#  43위 | Lovesick Girls | BLACKPINK
#  44위 | 밤하늘의 별을(2020) | 경서
#  45위 | Dolphin | 오마이걸 (OH MY GIRL)
#  46위 | 어푸 (Ah puh) | 아이유
#  47위 | 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 | AKMU (악뮤)
#  48위 | Off My Face | Justin Bieber
#  49위 | Blueming | 아이유
#  50위 | 추억은 만남보다 이별에 남아 | 정동하
#  51위 | 라라라 | SG 워너비
#  52위 | 아로하 | 조정석
#  53위 | 별빛 같은 나의 사랑아 | 임영웅
#  54위 | 가을 우체국 앞에서 | 김대명
#  55위 | 잠이 오질 않네요 | 장범준
#  56위 | LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지) | 양요섭, 정은지
#  57위 | THRILL RIDE | 더보이즈 (THE BOYZ)
#  58위 | 에잇(Prod.&Feat. SUGA of BTS) | 아이유
#  59위 | 비 오는 날 듣기 좋은 노래 (Feat. Colde) | 에픽하이 (EPIK HIGH)
#  60위 | 넌 좋은 사람 | SG 워너비
#  61위 | 취기를 빌려 (취향저격 그녀 X 산들) | 산들
#  62위 | 허리춤 | 오반 (OVAN)
#  63위 | 2002 | Anne-Marie
#  64위 | 슈퍼스타 | 미도와 파라솔
#  65위 | HERO | 임영웅
#  66위 | 그날에 나는 맘이 편했을까 | 이예준
#  67위 | METEOR | 창모 (CHANGMO)
#  68위 | 그대라는 사치 | 임영웅
#  69위 | On The Ground | 로제 (ROSÉ)
#  70위 | Coin | 아이유
#  71위 | VVS (Feat. JUSTHIS) (Prod. GroovyRoom) | 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM)
#  72위 | 전쟁터 (with 이선희) | AKMU (악뮤)
#  73위 | 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 | 장범준
#  74위 | 12:45 (Stripped) | Etham
#  75위 | 다시 사랑한다면 (김필 Ver.) | 임영웅
#  76위 | 마.피.아. In the morning | ITZY (있지)
#  77위 | 나랑 같이 걸을래 (바른연애 길잡이 X 적재) | 적재
#  78위 | Memories | Maroon 5
#  79위 | 고백 | 장범준
#  80위 | 모든 날, 모든 순간 (Every day, Every Moment) | 폴킴
#  81위 | 끝사랑 | 임영웅
#  82위 | 내사람 | SG 워너비
#  83위 | Bk Love | 임영웅
#  84위 | 오래된 노래 | 스탠딩 에그
#  85위 | 살짝 설렜어 (Nonstop) | 오마이걸 (OH MY GIRL)
#  86위 | 어떻게 지내 (Prod. By VAN.C) | 오반 (OVAN)
#  87위 | You can't sit with us | 선미
#  88위 | 너의 번호를 누르고 (Prod. 영화처럼) | #안녕
#  89위 | 나는 너 좋아 | 장범준
#  90위 | 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온) | 마크툽 (MAKTUB)
#  91위 | 사실 나는 (Feat.전건호) | 경서예지
#  92위 | How You Like That | BLACKPINK
#  93위 | 잊었니 | 임영웅
#  94위 | 이젠 잊기로 해요 (Drama Ver.) | 미도와 파라솔
#  95위 | 늦은 밤 너의 집 앞 골목길에서 | 노을
#  96위 | 난 너를 사랑해 | MSG워너비
#  97위 | Dance Monkey | Tones And I
#  98위 | 미워요 | 임영웅
#  99위 | 째깍 째깍 째깍 (with Beenzino) | AKMU (악뮤)
# 100위 | 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM) | 10CM

# %% [markdown]
# ## 2.3 정규표현식을 활용한 웹 데이터 수집
# 정규표현식 참조
# https://goo.gl/HLntbd <br>
# http://www.nextree.co.kr/p4327 <br><br>
# 정규표현식 연습장 : http://regexr.com<br><br>
# 간략 문법<br>
#     **\d** : 숫자와 매치, [0-9]와 동일<br>
#     **\D** : 숫자가 아닌 것<br>
#     **\s** : whitespace<br>
#     **\w** : 영문자나 숫자<br>
#     **\W** : 영문자나 숫자가 아닌 문자<br>
#     **.** : 문자 한개<br>
#     **+** : 한번 이상 반복<br>
#     * : 0번 이상 반복<br>
#     **{2,4}** : 2~4회 반복<br>
#     **?** : {0,1}의 의미<br>
#     **^** : 시작<br>
#     $ : 끝

# %%
# 예) 메일 주소, 전화번호, ip주소, 주민번호 등의 정규표현식

# %%
import re
parsing_string = """010-9999-9999 (02)716-6000 02.712.6100
02-716-0011 <city>서울</city>
"""

# %%
phone = re.findall(r'.?\d{2,3}.?\d{3,4}.\d{4}', parsing_string)

phone
# Out:
# ['010-9999-9999', '(02)716-6000', ' 02.712.6100', '02-716-0011']

# %%
tag_text = re.search(r'<city>(.+)</city>', parsing_string)

tag_text.group(1)
# Out:
# '서울'

# %%
tag = re.findall(r'<city>.+?</city>', parsing_string, re.DOTALL) # DOTALL : 줄바꿈 문자까지 포함

tag
# Out:
# ['<city>서울</city>']

# %%
# 특수문자 빼기
text = '이 영화 좋아요 ★ 이 영화 추천합니다. ♥'
msg = re.findall(r'[가-힣a-zA-Z0-9 ]', text)

''.join(msg)
# Out:
# '이 영화 좋아요  이 영화 추천합니다 '

# %% [markdown]
# ### 2.3.1 연습1) 전국 날씨 RSS 데이터 가져오기

# %%
import re, urllib.request
url = 'http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108'
target = urllib.request.urlopen(url)
contents = target.read().decode('UTF8')
locations = re.findall(r'<location wl_ver="3">.+?</location>', contents, 
                       re.DOTALL)

for loc in locations:
    province = re.search(r'<province>(.+)</province>', loc)
    city = re.search(r'<city>(.+)</city>', loc)
    print(province.group(1), "지역의", city.group(1), '날씨입니다.')
    
    data = re.findall(r'<data>.+?</data>', loc, re.DOTALL)
    for item in data:
        tmEf = re.search(r'<tmEf>(.+)</tmEf>', item).group(1)
        print(tmEf)
# Out:
# 서울ㆍ인천ㆍ경기도 지역의 서울 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 서울ㆍ인천ㆍ경기도 지역의 인천 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 서울ㆍ인천ㆍ경기도 지역의 수원 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 서울ㆍ인천ㆍ경기도 지역의 파주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 서울ㆍ인천ㆍ경기도 지역의 이천 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 서울ㆍ인천ㆍ경기도 지역의 평택 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 강원도영서 지역의 춘천 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 강원도영서 지역의 원주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 강원도영동 지역의 강릉 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대전ㆍ세종ㆍ충청남도 지역의 대전 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대전ㆍ세종ㆍ충청남도 지역의 세종 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대전ㆍ세종ㆍ충청남도 지역의 홍성 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 충청북도 지역의 청주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 충청북도 지역의 충주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 충청북도 지역의 영동 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 광주ㆍ전라남도 지역의 광주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 광주ㆍ전라남도 지역의 목포 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 광주ㆍ전라남도 지역의 여수 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 광주ㆍ전라남도 지역의 순천 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 광주ㆍ전라남도 지역의 광양 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 광주ㆍ전라남도 지역의 나주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 전라북도 지역의 전주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 전라북도 지역의 군산 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 전라북도 지역의 정읍 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 전라북도 지역의 남원 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 전라북도 지역의 고창 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 전라북도 지역의 무주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 부산ㆍ울산ㆍ경상남도 지역의 부산 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 부산ㆍ울산ㆍ경상남도 지역의 울산 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 부산ㆍ울산ㆍ경상남도 지역의 창원 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 부산ㆍ울산ㆍ경상남도 지역의 진주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 부산ㆍ울산ㆍ경상남도 지역의 거창 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 부산ㆍ울산ㆍ경상남도 지역의 통영 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대구ㆍ경상북도 지역의 대구 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대구ㆍ경상북도 지역의 안동 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대구ㆍ경상북도 지역의 포항 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대구ㆍ경상북도 지역의 경주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대구ㆍ경상북도 지역의 울진 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 대구ㆍ경상북도 지역의 울릉도 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 제주도 지역의 제주 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
# 제주도 지역의 서귀포 날씨입니다.
# 2021-08-13 00:00
# 2021-08-13 12:00
# 2021-08-14 00:00
# 2021-08-14 12:00
# 2021-08-15 00:00
# 2021-08-15 12:00
# 2021-08-16 00:00
# 2021-08-16 12:00
# 2021-08-17 00:00
# 2021-08-17 12:00
# 2021-08-18 00:00
# 2021-08-19 00:00
# 2021-08-20 00:00
